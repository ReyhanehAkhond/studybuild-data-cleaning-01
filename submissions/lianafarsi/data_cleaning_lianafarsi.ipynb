# %%
import pandas as pd

df = pd.read_excel("First Dataset.xlsx")

print("First 5 rows of the dataset:")
display(df.head())
# Out:
# First 5 rows of the dataset:
#    customer_id first_name gender   age     city  province signup_date  \
# 0         1001       Reza      F  19.0    Karaj    Alborz  2025-02-19
# 1         1002       Sina      M  53.0   Tehran    Tehran  2022-08-19
# 2         1003      Parsa      F  31.0   Shiraz      Fars  2023-06-20
# 3         1004       Sina      F  58.0  Mashhad  Khorasan  2021-11-08
# 4         1005      Kimia      M  28.0  Isfahan   Isfahan  2021-10-21
#
#   membership_tier  purchase_count  avg_order_value  total_spending  \
# 0             VIP              17           121.53         2066.01
# 1            Gold              12           326.47         3917.64
# 2            Gold              21            59.46         1248.66
# 3            Gold              23           266.15         6121.45
# 4          Silver              23           169.54         3899.42
#
#    last_purchase_days payment_method   device discount_used  returned_items  \
# ...

# %%
print("Missing values count per column:")
print(df.isnull().sum())
# Out:
# Missing values count per column:
# customer_id           0
# first_name            0
# gender                0
# age                   1
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        1
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# dtype: int64

# %%
import numpy as np

df['age'] = np.where(df['age'] > 100, np.nan, df['age'])
median_age = df['age'].median()
df['age'] = df['age'].fillna(median_age)

df['total_spending'] = df['purchase_count'] * df['avg_order_value']

df['data_quality_issue'] = np.where(df['returned_items'] > df['purchase_count'], 'Yes', 'No')

print("Missing values after applying new cleaning rules:")
print(df.isnull().sum())
# Out:
# Missing values after applying new cleaning rules:
# customer_id           0
# first_name            0
# gender                0
# age                   0
# city                  0
# province              0
# signup_date           0
# membership_tier       0
# purchase_count        0
# avg_order_value       0
# total_spending        0
# last_purchase_days    0
# payment_method        0
# device                0
# discount_used         0
# returned_items        0
# satisfaction_score    0
# data_quality_issue    0
# dtype: int64

# %%
duplicates_count = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates_count}")
# Out:
# Number of duplicate rows: 1

# %%
df = df.drop_duplicates()
print(f"Total rows after removing duplicates: {len(df)}")
# Out:
# Total rows after removing duplicates: 60

# %%
df['signup_date'] = pd.to_datetime(df['signup_date'], errors='coerce')
text_columns = ['first_name', 'gender', 'city', 'province', 'membership_tier', 'payment_method', 'device', 'discount_used']
for col in text_columns:
  if col in df.columns:
    df[col] = df[col].astype(str).str.strip()

print("Text columns cleaned and dates standardized successfully!")
# Out:
# Text columns cleaned and dates standardized successfully!

# %%
output_file = 'cleaned_dataset_lianafarsi.xlsx'
df.to_excel(output_file, index=False)
print(f"Dataset successfully cleaned and saved as '{output_file}'!")
# Out:
# Dataset successfully cleaned and saved as 'cleaned_dataset_lianafarsi.xlsx'!

# %%
import zipfile
import os

readme_content = """# Data Cleaning Project - First Dataset

This repository contains the first data cleaning project for processing and standardizing customer data using Python (Pandas).

## Project Overview
The goal of this project is to clean a raw dataset, handle missing data, remove duplicates, fix formatting issues, and prepare a clean, analysis-ready dataset.

## Files Included
- data_cleaning_lianafarsi.ipynb
- cleaned_dataset_lianafarsi.xlsx
- README.md
"""

with open('README.md', 'w', encoding='utf-8') as f:
    f.write(readme_content)

zip_filename = 'lianafarsi-data-cleaning.zip'


with zipfile.ZipFile(zip_filename, 'w') as zipf:
    for file in ['data_cleaning_lianafarsi.ipynb', 'cleaned_dataset_lianafarsi.xlsx', 'README.md']:
        if os.path.exists(file):
            zipf.write(file)
            print(f"Added {file} to zip.")

print(f"Zip file '{zip_filename}' created successfully!")
# Out:
# Added cleaned_dataset_lianafarsi.xlsx to zip.
# Added README.md to zip.
# Zip file 'lianafarsi-data-cleaning.zip' created successfully!
